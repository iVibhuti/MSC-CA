# %%
import io
import argparse
from collections import Counter
import json

def openfile(filename):
    strh = ''
    try:
        fh = open(filename, encoding="utf8") 
        strh = fh.readlines()
        return True, strh
    except Exception:
        return False,strh

#def train_bigram(training_file, model_file):
def train_bigram(filename):
    counts = Counter()
    context_counts = Counter()
    status, file = openfile(filename)
    try:
        for line in file:
            token = line.strip().split(' ')
            token.insert(0, '<s>')
            token.append('</s>')
            for i in range(1, len(token)): # starting at 1, after <s>
                    # Add bigram and bigram context.
                    counts[' '.join(token[i-1:i+1])] += 1  # Number of 'w_i, w_{i-1}'
                    context_counts[token[i-1]] += 1  # Number of w_{i-1}.
                    # Add unigram and unigram context.
                    counts[token[i]] += 1  # Number of w_i.
                    context_counts[''] += 1  # Total number of words.
    except FileNotFoundError:
        return 'File Not Found'
    probabilities = {}
    for ngram, count in sorted(counts.items(),key=lambda x:x[1],reverse=True):
        words = ngram.split(' ')
        context = words[:-1]
        context = ' '.join(context)
        probabilities[ngram] = count / context_counts[context]
        # Creates a file with bigram model for the file
        with open('model.json', 'w') as file:
            file.write(json.dumps(probabilities))

# %%
train_bigram('wiki-en-train.word')

# %%
import io
import argparse
import math

V = 1e6  # Vocabulary size.

def load_model(modelfile):
    with open(modelfile) as file:
        model = json.loads(file.read())
    return model

def test_bigram(lambdaval,probs, test_file):
        lambda_1 = lambdaval
        lambda_2 = 1 - lambda_1
        W = 0  # Total number of words.
        H = 0  # Negative log likelihood.
        with open(test_file, 'r') as f:   
            for line in f:
                words = line.strip().split(' ')
                words.insert(0, '<s>')
                words.append('</s>')
                for i in range(1, len(words)):
                    try:
                        P1 = lambda_1 * probs[words[i]] + (1 - lambda_1) / V
                        P2 = lambda_2 * probs[' '.join(words[i-1:i+1])] + (1 - lambda_2) * P1
                        H += - math.log2(P2)
                        W += 1
                        print('Entropy is : {}'.format(H/W))
                    except:
                        print('This words sequence is not in training data thaswhy the probability of theses coming together is zero.')

# %%
probs = load_model('model.json')

# %%
for lambdaval in [0.90,0.92,0.94,0.96]:
    print('For Lambda 2 value  '+str(1- lambdaval))
    test_bigram(lambdaval,probs,'02-train-input.txt')
# Out:
# For Lambda 2 value  0.09999999999999998
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# For Lambda 2 value  0.07999999999999996
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# For Lambda 2 value  0.06000000000000005
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# For Lambda 2 value  0.040000000000000036
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.

# %%
for lambdaval in [0.90,0.92,0.94,0.96]:
    print('For Lambda 2 value  '+str(1- lambdaval))
    test_bigram(lambdaval,probs,'wiki-en-test.word')
# Out:
# For Lambda 2 value  0.09999999999999998
# Entropy is : 6.7174672910413085
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.50513051385728
# Entropy is : 5.010303708237251
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.2281063526491405
# Entropy is : 5.807783844022301
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 6.132775768067855
# Entropy is : 5.805949464322926
# Entropy is : 5.6754345050229675
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.810810324942931
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 6.158376189242388
# Entropy is : 5.9796997588691365
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.901475303238677
# Entropy is : 6.04204899663264
# Entropy is : 6.020492516669309
# Entropy is : 6.182047074053941
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 6.16326377479337
# Entropy is : 6.294664108654638
# Entropy is : 6.246402264453937
# Entropy is : 6.175699028400683
# Entropy is : 6.222858392997116
# Entropy is : 6.107658439458884
# Entropy is : 6.240313863234527
# Entropy is : 6.1577009429434275
# Entropy is : 6.219896445167382
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 6.136660963418127
# Entropy is : 6.015322577979404
# Entropy is : 6.0341895109857475
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 6.041207558114431
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 6.072836829491972
# Entropy is : 6.002943108315931
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.929881133167848
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.837755564694207
# Entropy is : 5.9565734452767884
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.908673946806485
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.893961582547755
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.813069953643965
# Entropy is : 5.884457279302633
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.883806506176698
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.8310259920451
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.854421849163462
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.843185735714376
# Entropy is : 5.902681131687539
# Entropy is : 5.8629196043258895
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.897154210178695
# Entropy is : 5.855953563513178
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.880489214268811
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.8188163148590775
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.765654934575758
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.767574791023541
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.805408747418422
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.800842676190009
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.746631527455804
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.694466082447418
# Entropy is : 5.713410549273231
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.675259064279785
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.627162704953562
# Entropy is : 5.7045681384743485
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.707243306785431
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.677790559305431
# Entropy is : 5.746916860767133
# Entropy is : 5.716139285878622
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.6924143113935095
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.723634284399448
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.680794107174633
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.70514285017048
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.687080972860475
# Entropy is : 5.6467045843403385
# Entropy is : 5.659616719411079
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.650651350887783
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.719816704340932
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.696394842090127
# Entropy is : 5.760530564647261
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.786870314217893
# Entropy is : 5.792261019377546
# Entropy is : 5.7804047495117405
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.792230907223832
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.755732621961331
# Entropy is : 5.76559155974581
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.729222426409928
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.767264449765822
# Entropy is : 5.7461484008123405
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.735952978355842
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.775954734987791
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.773089809631908
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.784781226892469
# Entropy is : 5.774919735895267
# Entropy is : 5.765592360795961
# Entropy is : 5.74617499856571
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.71870643618001
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.709335031760432
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.693182498923888
# Entropy is : 5.730627404527007
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.717996162020561
# Entropy is : 5.688888361807698
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.663770372386533
# Entropy is : 5.648993502547107
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.6344621730737865
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.610668470968922
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.5997983868523935
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.573619032403983
# Entropy is : 5.583035970391574
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.5699198419348095
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.544793075916136
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.565175662248494
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.592278123164693
# Entropy is : 5.581254484564433
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.570953529028098
# Entropy is : 5.6039827909297895
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.602350699223836
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.620969265561059
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.6082390346220805
# Entropy is : 5.62029972932377
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.606464019192885
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.61304644751996
# Entropy is : 5.599514430450515
# Entropy is : 5.640157985931147
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.624461416553054
# Entropy is : 5.616155356598272
# Entropy is : 5.6332497905455
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.634994925053461
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.621952524718588
# Entropy is : 5.66041329800945
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.638636465846864
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.638103422693013
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.648033510602521
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.639826263040511
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.640372422497075
# Entropy is : 5.628345246507258
# Entropy is : 5.6386606852258945
# Entropy is : 5.639467823553437
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.629955595470259
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.642330647034155
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.642701475178543
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.631479892538674
# Entropy is : 5.611853100312546
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.607578247423898
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.621606378154819
# Entropy is : 5.615927594254486
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.604711312889588
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# ...
# Entropy is : 5.942172663198125
# Entropy is : 5.94026949520861
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.938369737914416
# Entropy is : 5.940280548255558
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.9423158206399815
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.9404193278198285
# Entropy is : 5.944829676919547
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.942934325160375
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.941042351924839
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.94479550680956
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.946610547961442
# Entropy is : 5.9486485561645805
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.949694700170135
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.9508114015470355
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.9505984996888825
# Entropy is : 5.950104391871702
# Entropy is : 5.9527826220830775
# Entropy is : 5.9514073271486065
# Entropy is : 5.952614068446006
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.952483739472612
# Entropy is : 5.953591088160852
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.951711395884841
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.950415019099231
# Entropy is : 5.952362923650365
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.950893861947123
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.9490231389382915
# Entropy is : 5.9502172181817645
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.94895694382065
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.947092831220885
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.945231980410445
# Entropy is : 5.948671517597339
# Entropy is : 5.947022774623122
# Entropy is : 5.950984401328744
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.95295888317069
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.953533855922274
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.956837931130627
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.9566238617170795
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.956102387533304
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.95424825382441
# Entropy is : 5.955806479636365
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.956485194277637
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.959892607803582
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.96226658866085
# Entropy is : 5.9604036441543835
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.961813820023566
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# This words sequence is not in training data thaswhy the probability of theses coming together is zero.
# Entropy is : 5.959965956809471
