# %%
from collections import Counter

# Opening the file
def open_file(location , file = ''):
    try:
        file = open(location , 'r')
        return True, file
    except Exception:
        return False, file

# Closing the file
def close_file(file):
    try:
        file.close()
        return True
    except Exception:
        return False

# Function to keep count of each word of the text
def occurence_count(text):
    counts = Counter()
    counts.update(word.strip('.,?!"\'').lower() for word in text.split())
    return counts

# main
flag , file = open_file('wiki-en-train.word')
if flag:
    # print(file.read())
    # for key , value in occurence_count(file.read()).items():
    #     print(key, value) '''
    # print(occurence_count('Tejas Tejas is a Boy,? boY.'))
    print(occurence_count(file.read()))
    close_file(file)
else:
    print('Something went wrong while reading the file.')
# Out:
# Counter({'': 3092, '<td': 2602, 'the': 1492, '<tr>': 1301, 'class="blob-num': 1301, 'js-line-number': 1301, 'class="blob-code': 1301, 'blob-code-inner': 1301, '</td>': 1301, '</tr>': 1301, 'of': 1131, 'a': 827, 'to': 795, 'and': 693, 'in': 555, 'is': 493, '-rrb-': 369, '-lrb-': 350, '0': 314, 'as': 292, 'that': 284, 'for': 281, 'are': 242, 'be': 239, 'or': 234, 'on': 217, '&#39;&#39;': 194, 'with': 186, '``': 184, 'can': 181, 'by': 180, 'speech': 168, 'text': 163, 'language': 159, 'js-file-line">the': 147, 'an': 141, 'which': 138, 'recognition': 127, 'such': 123, 'it': 122, 'this': 121, 'systems': 116, 'not': 113, 'used': 113, 'words': 111, 'have': 108, '<div': 106, 'from': 106, ':': 102, 'more': 97, 'js-file-line">in': 97, '</div>': 94, 'system': 94, 'some': 88, 'machine': 85, 'has': 84, 'natural': 81, 'example': 81, '16': 78, 'data': 78, 'into': 78, 'sentences': 77, 'was': 77, 'translation': 76, '<span': 73, 'use': 73, 'at': 70, 'other': 70, 'analysis': 70, 'also': 69, 'been': 68, 'but': 68, 'one': 66, '1': 65, 'word': 62, 'using': 59, '<a': 58, 'processing': 58, 'most': 58, 'evaluation': 58, 'js-file-line">for': 57, 'may': 55, 'based': 54, 'e.g': 54, 'would': 53, 'many': 53, 'js-file-line">this': 52, 'summarization': 52, '&#39;s': 51, 'different': 51, 'all': 50, 'computer': 50, 'languages': 50, 'information': 50, 'sentence': 50, '<svg': 48, 'class="octicon': 48, 'viewbox="0': 48, 'version="1.1': 48, 'fill-rule="evenodd': 48, 'research': 48, 'human': 47, 'corpus': 47, ';': 47, 'nlp': 46, 'each': 46, 'problem': 45, 'than': 45, 'rules': 45, 'methods': 45, 'ocr': 45, 'we': 45, 'height="16': 44, 'learning': 44, 'number': 44, 'often': 44, 'task': 44, 'js-file-line">a': 44, 'question': 44, 'input': 43, 'these': 43, 'summaries': 43, 'about': 42, 'there': 42, 'summary': 42, 'very': 41, 'were': 41, 'set': 40, 'they': 40, '<meta': 39, 'aria-hidden="true"><path': 39, 'when': 39, 'only': 39, 'between': 39, 'statistical': 39, 'what': 39, 'documents': 39, '%': 39, '</a>': 38, 'grammar': 38, 'document': 38, 'd-none': 37, 'new': 37, 'process': 37, 'js-file-line">however': 37, 'will': 36, 'english': 36, 'discourse': 36, '8': 35, 'understanding': 35, 'algorithms': 35, 'where': 35, 'approach': 35, 'given': 35, 'its': 35, 'then': 35, 'keyphrases': 35, 'time': 34, 'js-file-line">it': 34, 'segmentation': 34, 'their': 34, 'first': 33, 'accuracy': 33, 'context': 33, 'both': 32, 'tasks': 32, 'usually': 32, 'extraction': 32, 'how': 32, 'any': 31, 'answer': 31, '<button': 30, 'training': 30, 'model': 30, 'so': 30, 'if': 30, 'because': 29, 'article': 29, 'models': 29, 'two': 29, 'algorithm': 29, 'like': 29, 'parsing': 29, 'software': 29, '</button>': 28, 'type="hidden': 28, 'knowledge': 28, 'well': 28, 'difficult': 28, 'approaches': 28, '`': 27, 'flex-shrink-0': 27, 'field': 27, 'similar': 27, 'part': 27, 'known': 27, 'even': 27, 'questions': 27, 'include': 27, '</span>': 26, 'output': 26, 'written': 26, 'developed': 26, 'do': 26, 'features': 26, 'tagging': 26, 'simple': 26, 'sentiment': 26, '/><meta': 25, '2': 25, '--': 25, 'see': 25, 'automatic': 25, 'might': 25, 'common': 25, 'same': 25, 'applications': 25, 'technology': 25, 'data-ga-click="header': 24, '4': 24, 'complex': 24, 'examples': 24, 'work': 24, 'possible': 24, 'determine': 24, 'character': 24, 'way': 24, 'source': 24, 'linguistics': 23, 'produce': 23, 'large': 23, 'general': 23, 'semantic': 23, 'meaning': 23, 'techniques': 23, '12': 22, 'create': 22, 'world': 22, 'program': 22, 'much': 22, 'up': 22, 'automatically': 22, 'those': 22, 'while': 22, 'etc': 22, 'several': 22, 'speaker': 22, 'levels': 22, 'width="16': 21, '-': 21, 'require': 21, 'years': 21, 'results': 21, 'specific': 21, 'sound': 21, 'needed': 21, 'need': 21, 'go': 20, 'you': 20, 'out': 20, 'them': 20, 'make': 20, 'form': 20, 'level': 20, 'domain': 20, 'keyphrase': 20, 'qa': 20, '<link': 19, '/>': 19, 'class="d-flex': 19, 'class="js-selected-navigation-item': 19, '&#39;': 19, 'i.e': 19, 'js-file-line">-lrb-': 19, 'should': 19,  ...
